# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_qdrant import QdrantVectorStore
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from qdrant_client import QdrantClient
url=os.getenv("QDRANT_URL"),
api_key=os.getenv("QDRANT_API_KEY"),
embeddings=GoogleGenerativeAIEmbeddings(
            model="models/text-embedding-004"  
        )
client = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY")
)
vector_store=QdrantVectorStore(
    client=client,
    collection_name="embedding_data",
    embedding=embeddings
)
def retrieval_vdb(input,top_k=4,score_threshold=0.8):
    retriever=vector_store.as_retriever(
        search_type='similarity_score_threshold',
        search_kwargs={'k':top_k,'score_threshold':score_threshold}
        )
    docs=retriever.invoke(input)
    return docs

retrieval_vdb("tôi bị đau bụng")
# Out:
# /Users/lebaminhphuc/anaconda3/envs/llms/lib/python3.11/site-packages/google/rpc/__init__.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ...

# %%
a=prompt.invoke({"input": "Xin chào", "chat_history": chat_history})
print(a)
# Out:
# messages=[SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Xin chào', additional_kwargs={}, response_metadata={}), AIMessage(content='Chào bạn! Cần giúp đỡ với điều gì không?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Xin chào', additional_kwargs={}, response_metadata={})]

# %%
from get_long_term import get_data
get_data()
# Out:
# 'Người dùng thích ăn đồ ngọt'

# %%
from expand_query import llm_expand_query
query="Tôi bị đau đầu và sốt cao, bạn có thể tư vấn cho tôi loại thuốc nào phù hợp không?"
llm_expand_query.invoke(query)
# Out:
# ['1. Tôi bị đau đầu và sốt cao, bạn có thể tư vấn cho tôi loại thuốc nào phù hợp không?',
#  '2. Thuốc nào thường được sử dụng để giảm đau đầu và sốt cao như trường hợp của bạn?',
#  '3. Liều lượng và cách sử dụng thuốc giảm đau đầu và sốt cao đúng cách là gì?',
#  '4. Có tác dụng phụ nào cần lưu ý khi sử dụng thuốc giảm đau đầu và sốt cao không?']

# %%
from IPython.display import display, Markdown
from chatbot_main import chatbot_response
display(Markdown(chatbot_response.invoke("Tôi bị đau bụng do ăn đồ bẩn, bạn có thể tư vấn cho tôi loại thuốc nào phù hợp không?")))
# Out:
# /Users/lebaminhphuc/anaconda3/envs/llms/lib/python3.11/site-packages/google/rpc/__init__.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Đối với việc đau bụng do ăn đồ bẩn, bạn có thể cần sử dụng thuốc chống vi khuẩn như thuốc metronidazole hoặc ciprofloxacin. Tuy nhiên, việc sử dụng chúng cần tuân theo hướng dẫn của bác sĩ để tránh các tác dụng phụ hoặc sự không phù hợp với cơ thể của bạn.
#
# Ngoài ra, việc mất nước do tiêu chảy cũng là một vấn đề thường gặp trong trường hợp ăn đồ bẩn. Do đó, việc sử dụng các loại thuốc hỗ trợ cung cấp điện giải và tái tạo nước như Oral Rehydration Salts cũng là một phương pháp hữu hiệu.
#
# ...

# %%
Markdown
from IPython.display import display, Markdown
